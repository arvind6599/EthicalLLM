# %%
# !pip install datasets
# !pip install transformers
# !pip install peft
# !pip install evaluate
# !pip install tqdm 
# !pip install gpustat
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, Trainer
from datasets import load_dataset
from tqdm.notebook import tqdm
import time
import json
import random
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: datasets in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (1.21.5)
# Requirement already satisfied: aiohttp in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow-hotfix in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (16.0.0)
# Requirement already satisfied: pandas in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (1.4.2)
# Requirement already satisfied: multiprocess in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (2024.3.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (2.27.1)
# Requirement already satisfied: filelock in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: xxhash in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: packaging in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.6.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (5.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->datasets) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: colorama in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: transformers in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (4.40.1)
# Requirement already satisfied: filelock in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (1.21.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (2022.3.15)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: requests in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->transformers) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->transformers) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Collecting peft
#   Using cached peft-0.10.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: huggingface-hub>=0.17.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (0.22.2)
# Requirement already satisfied: psutil in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (5.8.0)
# Requirement already satisfied: transformers in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (4.40.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (21.3)
# Requirement already satisfied: pyyaml in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (6.0)
# Requirement already satisfied: safetensors in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (0.4.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (1.21.5)
# Collecting torch>=1.13.0
#   Using cached torch-2.3.0-cp39-cp39-win_amd64.whl (159.7 MB)
# Collecting accelerate>=0.21.0
#   Using cached accelerate-0.29.3-py3-none-any.whl (297 kB)
# Requirement already satisfied: tqdm in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from peft) (4.64.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub>=0.17.0->peft) (2024.3.1)
# Requirement already satisfied: filelock in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub>=0.17.0->peft) (3.6.0)
# Requirement already satisfied: requests in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub>=0.17.0->peft) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from huggingface-hub>=0.17.0->peft) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from packaging>=20.0->peft) (3.0.4)
# Requirement already satisfied: networkx in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from torch>=1.13.0->peft) (2.7.1)
# Collecting mkl<=2021.4.0,>=2021.1.1
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Requirement already satisfied: sympy in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from torch>=1.13.0->peft) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from torch>=1.13.0->peft) (2.11.3)
# Collecting tbb==2021.*
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Collecting intel-openmp==2021.*
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Requirement already satisfied: colorama in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from tqdm->peft) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from jinja2->torch>=1.13.0->peft) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.17.0->peft) (2021.10.8)
# Requirement already satisfied: mpmath>=0.19 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from sympy->torch>=1.13.0->peft) (1.2.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from transformers->peft) (2022.3.15)
# Installing collected packages: tbb, intel-openmp, mkl, torch, accelerate, peft
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: evaluate in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: packaging in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (21.3)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (0.22.2)
# Requirement already satisfied: multiprocess in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: pandas in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (1.4.2)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (4.64.0)
# Requirement already satisfied: dill in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: responses<0.19 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (1.21.5)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (2.19.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from evaluate) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.6.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.8.1)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (16.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.6.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (5.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->datasets>=2.0.0->evaluate) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from packaging->evaluate) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (1.26.9)
# Requirement already satisfied: colorama in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from pandas->evaluate) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (4.64.0)
# Requirement already satisfied: colorama in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: gpustat in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: blessed>=1.17.1 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from gpustat) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from gpustat) (12.550.52)
# Requirement already satisfied: psutil>=5.6.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from gpustat) (5.8.0)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from blessed>=1.17.1->gpustat) (0.2.5)
# Requirement already satisfied: jinxed>=1.1.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from blessed>=1.17.1->gpustat) (1.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from blessed>=1.17.1->gpustat) (1.16.0)
# Requirement already satisfied: ansicon in c:\users\tanu.desktop-d6i4pbo\anaconda3\lib\site-packages (from jinxed>=1.1.0->blessed>=1.17.1->gpustat) (1.89.0)
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # the device to load the model onto

# specify how to quantize the model
quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # the device to load the model onto
#       3 # specify how to quantize the model
#       4 quantization_config = BitsAndBytesConfig(
#       5         load_in_4bit=True,
#       6         bnb_4bit_quant_type="nf4",
#       7         bnb_4bit_compute_dtype=torch.float16,
#       8 )
#
# NameError: name 'torch' is not defined

# %%
# Load the Hugging Face dataset
with open("/home/srsingh/scratchsrsingh/revised_datafile.json", "r") as json_file:
    dataset = json.load(json_file)
random.shuffle(dataset)

# Split the dataset into training and evaluation sets (80% training, 20% evaluation)
train_data, eval_data = train_test_split(dataset, test_size=0.2, random_state=42)

# Label the data
for example in train_data:
    example["split"] = "train"  # Add a label indicating this example is for training

for example in eval_data:
    example["split"] = "eval"  # Add a label indicating this example is for evaluation
    
with open("train_dataset.json", "w") as train_file:
    json.dump(train_data, train_file)

with open("eval_dataset.json", "w") as eval_file:
    json.dump(eval_data, eval_file)

#dataset = load_dataset("imdb", split="train")
# Define the input and label columns
input_column = "prompt"
label_column = "revised_answer"
tokenizer.pad_token = tokenizer.eos_token
tokenized_train = tokenizer(
    [example["prompt"] for example in train_data],
    [example["revised_answer"] for example in train_data],
    padding="max_length",
    truncation=True,
    max_length=512,  # Adjust max_length according to your sequence length requirements
)
tokenized_eval = tokenizer(
    [example["prompt"] for example in eval_data],
    [example["revised_answer"] for example in eval_data],
    padding="max_length",
    truncation=True,
    max_length=512,  # Adjust max_length according to your sequence length requirements
)

tokenized_dataset = {"train": tokenized_train, "eval": tokenized_eval}


# Fine-tune the Mistral 7B model
#model = AutoModelForSequenceClassification.from_pretrained(model, num_labels=len(
   # set(tokenized_dataset["train"][label_column])))

training_args = TrainingArguments(
   output_dir="./fine-tuned-model",
   evaluation_strategy="epoch",
   learning_rate=2e-5,
   per_device_train_batch_size=4,
   per_device_eval_batch_size=4,
   num_train_epochs=4,
   weight_decay=0.01,
)

trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=tokenized_dataset["train"]
)

trainer.train()
results = trainer.evaluate()
print(results)
